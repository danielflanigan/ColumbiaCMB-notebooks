# %%
from scipy.constants import mu_0, pi

# %%
sigma = 3.8016e7
fM = 150e6
fG = 150e9

# %%
dM = (pi * fM * mu_0 * sigma )**(-1/2)
1e6 * dM # in microns
# Out:
# 6.6648640121992795

# %%
dG = (pi * fG * mu_0 * sigma )**(-1/2)
1e6 * dG # in microns
# Out:
# 0.21076150573837976

# %%
f = np.logspace(1, 15, 1500)
f
# Out:
# array([  1.00000000e+01,   1.02173803e+01,   1.04394861e+01, ...,
#          9.57901560e+14,   9.78724456e+14,   1.00000000e+15])

# %%
delta = (pi * f * mu_0 * sigma)**(-1/2)
eta = (sigma * delta)**-1

# %%
plt.loglog(f, delta)

# %%
plt.loglog(f, eta)
