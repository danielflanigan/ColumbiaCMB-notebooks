# %%
from scipy.special import jn_zeros, jnp_zeros, jnjnp_zeros
from physics.electromagnetism import waveguide

# %%
jnjnp_zeros(6)
# Out:
# (array([ 0.        ,  1.84118378,  2.40482556,  3.05423693,  3.83170597,
#          3.83170597]),
#  array([0, 1, 0, 2, 1, 0], dtype=int32),
#  array([0, 1, 1, 1, 1, 1], dtype=int32),
#  array([1, 1, 0, 1, 0, 1], dtype=int32))

# %%
jn_zeros(1, 1)
# Out:
# array([ 3.83170597])

# %%
jnp_zeros(0, 1)
# Out:
# array([ 3.83170597])

# %%
plt.plot(jnjnp_zeros(1200)[0], '.')
#plt.plot(jn_zeros(1, 13), '.')

# %%
circ = waveguide.Circular(1.35e-3 / 2)

# %%
circ.f_0 / 1e9
# Out:
# 130.14701218318999

# %%
c3 = circ.cutoffs_below(3*circ.f_0)
c10 = circ.cutoffs_below(10*circ.f_0)

# %%
ff = np.linspace(c3[0]*0.9, c3[-1]*1.1, 1000)
plt.plot(ff/1e9, np.searchsorted(c3, ff))

# %%
ff = np.linspace(c10[0]*0.9, c10[-1]*1.1, 1e4)
plt.plot(ff/1e9, np.searchsorted(c10, ff))

# %%
jnjnp_zeros(1200)[0][-1] / jnjnp_zeros(1)[-1]
# Out:
# array([ 68.56313857])

# %%
circ.propagating_modes([150e9])
# Out:
# array([1])
