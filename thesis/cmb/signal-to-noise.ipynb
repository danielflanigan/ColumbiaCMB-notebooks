# %%
from scipy.constants import c, h, k as k_B, pi

# %%
d = 1e12
B = 33e9
s2t = d + d**2 / B
signal_to_noise = 1e9

# %%
bulb = 10  # W
cmb = 0.1e-12  # in space
A = 0.1**2  # area of one hand
r2 = (bulb / cmb) * A / (4 * pi)
print('{:.0f} km'.format(1e-3 * r2**(1/2)))
# Out:
# 892 km

# %%
T_cmb = 2.725
1e-9 * k_B * T_cmb / h
# Out:
# 56.77976831346624

# %%
def occupancy(nu, T):
    return 1 / (np.exp(h * nu / (k_B * T)) - 1)

# %%
n = np.linspace(10e9, 200e9, 10000)
fig, ax = plt.subplots()
ax.plot(1e-9 * n, occupancy(nu=n, T=T_cmb))
ax.set_xlabel('$\nu$ / \GHz')
