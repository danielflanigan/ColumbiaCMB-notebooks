# %% [markdown]
# The new (2014-10) standard curve seems to be the same as the older one but with far fewer points, so there's no reason to switch.

# %%
# %matplotlib inline

# %%
r_old, t_old = np.loadtxt('/Users/daniel/Downloads/ro600.txt', unpack=True)
t_new, r_new = np.loadtxt('/Users/daniel/Downloads/Standard-RO600.txt', unpack=True, skiprows=7)
r_new = r_new[::-1]
t_new = t_new[::-1]
r_cal, t_cal = np.loadtxt('/Users/daniel/Downloads/3882cal_vs_3628.txt', unpack=True)

# %%
fig, ax = plt.subplots()
ax.set_xlabel('resistance / $\Omega$')
ax.set_ylabel('temperature / K')
ax.set_xscale('log')
ax.set_yscale('log')
ax.plot(r_old, t_old, '.', label='old')
ax.plot(r_new, t_new, '-', label='new')
ax.plot(r_cal, t_cal, '.', label='cal')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.set_xlabel('resistance / $\Omega$')
ax.set_ylabel('temperature / K')
ax.plot(r_old, t_old, '.', label='old')
ax.plot(r_new, t_new, '-', label='new')
ax.plot(r_cal, t_cal, '.', label='cal')
ax.legend()
ax.set_ylim(0, 0.4)
ax.set_xlim(0.3e4, 3e4)
# Out:
# (3000.0, 30000.0)
