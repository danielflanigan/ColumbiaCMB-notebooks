# %%
from glob import glob
from kid_readout.utils import parse_srs

# %%
latest = sorted(glob('/home/heather/SRS/2*.txt'))[-1]

# %%
latest
# Out:
# '/home/heather/SRS/20140630-202443.txt'

# %%
datetimes, srs_data = parse_srs.get_load_log(latest)
timedeltas = [dt - datetimes[0] for dt in datetimes]

# %%
fig, ax = plt.subplots()
time_hours = [td.total_seconds()/3600 for td in timedeltas]
ax.plot(time_hours, srs_data[:, -4], label='package')
ax.plot(time_hours, srs_data[:, 1], label='diode 1')
ax.plot(time_hours, srs_data[:, 2], label='diode 2')
ax.set_xlabel('time / [hours]')
ax.set_ylabel('temperature / [K]')
ax.set_ylim(4, 6)
ax.legend();
