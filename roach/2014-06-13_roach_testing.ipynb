# %%
from kid_readout.utils import roach_interface, roach_utils, valon, borph_utils
import time

# %%
ri = roach_interface.RoachBasebandWide()
ri.initialize()
# Out:
# Loaded ROACH state from /home/data/roach_config.npz

# %%
# How accurate is this function? Is the spread due to measurement or due to sampling clock variations?

measured_sample_rates_MHz = []
for x in range(20):
    measured_sample_rates_MHz.append(ri.measure_fs())
    time.sleep(2)

# %%
fractional_mean = np.mean(measured_sample_rates_MHz) / 512
fractional_fluctuation = np.std(measured_sample_rates_MHz) / 512

# %%
fractional_fluctuation
# Out:
# 0.00019597405438104203

# %%
fractional_mean - 1
# Out:
# 0.0015325324218751213

# %%
fig, ax = plt.subplots()
ax.plot(np.array(measured_sample_rates_MHz) - 512, '.')
ax.set_xlabel('sample index')
ax.set_ylabel('difference from nominal [MHz]')
