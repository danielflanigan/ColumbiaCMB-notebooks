# %%
# %matplotlib inline
display.hide_code()
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %%
mpl.get_configdir()
# Out:
# u'/home/flanigan/.config/matplotlib'

# %%
mpl.matplotlib_fname()
# Out:
# u'/home/flanigan/.config/matplotlib/matplotlibrc'

# %%
mpl.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
fig, ax = plt.subplots()
ax.set_xlabel(r'$10^6 x_y$ [arbs]')
ax.set_ylabel(r'$10^6 x_y$ [arbs]')
ax.set_title('title')
ax.plot(np.arange(0, 1e4, 1e3), '.')
fig.savefig('/home/flanigan/test.pdf')
