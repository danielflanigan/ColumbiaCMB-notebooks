# %% [markdown]
# Pick this up again if we decide we need to pickle Resonator objects. We could save only the Parameters object and not the Minimizer.

# %%
import pickle
from kid_readout.analysis import resonator, noise_measurement
plt.rcParams['font.size'] = 11
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
filename = '/home/data2/2014-11-26_123025_35_dB.nc'  # one sweep and timestream for 16 resonators

# %%
snm = noise_measurement.SweepNoiseMeasurement(filename)
# Out:
# using NFFT: 2** 16.0
# 10
# /home/flanigan/kid_readout.git/kid_readout/analysis/iqnoise.py:75: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[0,k] = ss[0,0]
# /home/flanigan/kid_readout.git/kid_readout/analysis/iqnoise.py:76: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[1,k] = ss[1,1]

# %%
r = resonator.Resonator(snm.sweep_freqs_MHz, snm.sweep_s21)

# %%
r.result.values
# Out:
# {'A_mag': 0.031659199317690678,
#  'A_phase': 0,
#  'Q': 57602.261674984948,
#  'Q_e_imag': 34438.977556912228,
#  'Q_e_real': 78405.611813916636,
#  'delay': -63.346775864066224,
#  'f_0': 96.06478083871535,
#  'f_phi': 96.05517578125,
#  'phi': 3.12524017593572}

# %%
r.result.params.valuesdict()
# Out:
# OrderedDict([('f_0', 96.06478083871535), ('A_mag', 0.031659199317690678), ('A_phase', 0), ('Q', 57602.261674984948), ('Q_e_real', 78405.611813916636), ('Q_e_imag', 34438.977556912228), ('delay', -63.346775864066224), ('phi', 3.12524017593572), ('f_phi', 96.05517578125)])

# %%
pickle.dump(r, open('resonator.pkl', 'w'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a406279d21c3> in <module>()
# ----> 1 pickle.dump(r, open('resonator.pkl', 'w'))
#
# /home/local/lib/python2.7/pickle.pyc in dump(obj, file, protocol)
#    1368
#    1369 def dump(obj, file, protocol=None):
# -> 1370     Pickler(file, protocol).dump(obj)
#    1371
#    1372 def dumps(obj, protocol=None):
#
# /home/local/lib/python2.7/pickle.pyc in dump(self, obj)
#     222         if self.proto >= 2:
#     223             self.write(PROTO + chr(self.proto))
# --> 224         self.save(obj)
#     225         self.write(STOP)
#     226
#
# /home/local/lib/python2.7/pickle.pyc in save(self, obj)
#     329
#     330         # Save the reduce() output and finally memoize the object
# --> 331         self.save_reduce(obj=obj, *rv)
#     332
#     333     def persistent_id(self, obj):
#
# ...

# %%
p = noise_measurement.load_noise_pkl('/home/data2/2014-11-26_123025_35_dB.pkl')

# %%
p[0].plot();

# %%
# %run ~/kid_readout.git/apps/data_analysis_scripts/mmw_noise_blackbody_archive.py
# Out:
# processing /home/data/2014-11-26_133127_41_dB.pkl
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/flanigan/kid_readout.git/apps/data_analysis_scripts/mmw_noise_blackbody_archive.py in <module>()
#     173         df = build_archive(info,
#     174                        force_rebuild=False,
# --> 175                        archive_name=None)
#     176         globals()[dfn] = df
#     177
#
# /home/flanigan/kid_readout.git/apps/data_analysis_scripts/mmw_noise_blackbody_archive.py in build_archive(info, archive_name, force_rebuild)
#      56         print "processing",fname
#      57         pkl = load_noise_pkl(fname)
# ---> 58         noise_on = pkl['noise_on_measurements']
#      59         noise_on_orig = noise_on
#      60         if len(noise_on) > len(info['index_to_resnum']):
#
# TypeError: list indices must be integers, not str

# %%
with open('params.pkl', 'w') as f:
    pickle.dump(r.result.params, f)

# %%
params = pickle.load(open('params.pkl'))

# %%
params
# Out:
# Parameters([('f_0', <Parameter 'f_0', value=96.06478083871535 +/- 1.17e-05, bounds=[96.03564453125:96.09423828125]>), ('A_mag', <Parameter 'A_mag', value=0.031659199317690678 +/- 9.39e-05, bounds=[0:1000000.0]>), ('A_phase', <Parameter 'A_phase', value=0 (fixed), bounds=[-3.141592653589793:3.141592653589793]>), ('Q', <Parameter 'Q', value=57602.261674984948 +/- 836, bounds=[0:10000000.0]>), ('Q_e_real', <Parameter 'Q_e_real', value=78405.611813916636 +/- 983, bounds=[0:1000000.0]>), ('Q_e_imag', <Parameter 'Q_e_imag', value=34438.977556912228 +/- 1.01e+03, bounds=[-1000000.0:1000000.0]>), ('delay', <Parameter 'delay', value=-63.346775864066224 +/- 0.0934, bounds=[-inf:inf]>), ('phi', <Parameter 'phi', value=3.12524017593572 +/- 0.00655, bounds=[-3.141592653589793:3.141592653589793]>), ('f_phi', <Parameter 'f_phi', value=96.05517578125 (fixed), bounds=[-inf:inf]>)])

# %%
params['f_0']
# Out:
# <Parameter 'f_0', value=96.06478083871535 +/- 1.17e-05, bounds=[96.03564453125:96.09423828125]>

# %%
dir(r.result)
# Out:
# ['_Minimizer__jacobian',
#  '_Minimizer__prepared',
#  '_Minimizer__residual',
#  '_Minimizer__set_params',
#  '_Minimizer__update_paramval',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'asteval',
#  'chisqr',
#  'covar',
#  'err_maxfev',
#  'err_nonparam',
#  'errorbars',
#  'fmin',
#  'ier',
#  'iter_cb',
#  'jacfcn',
#  'kws',
#  'lbfgsb',
#  'leastsq',
#  'lmdif_message',
#  'message',
#  'minimize',
#  'namefinder',
#  'ndata',
#  'nfev',
#  'nfree',
#  'nvarys',
#  'params',
#  'penalty',
#  'prepare_fit',
#  'redchi',
#  'residual',
#  'scalar_minimize',
#  'scale_covar',
#  'success',
#  'unprepare_fit',
#  'update_constraints',
#  'updated',
#  'userargs',
#  'userfcn',
#  'userkws',
#  'values',
#  'var_map',
# ...
