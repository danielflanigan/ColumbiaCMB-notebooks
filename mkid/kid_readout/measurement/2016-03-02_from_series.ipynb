# %%
import os
import pandas as pd
from kid_readout.measurement import core, legacy
from kid_readout.measurement.io import npy, readoutnc
from kid_readout.analysis.resonator import plot_resonator
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
root_path = '/home/flanigan/temp/npy'
node_path = 'ss'

# %%
df = pd.DataFrame().from_records(np.load(os.path.join(root_path, 'dataframe.npy')))

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
fs = core.from_series(df.iloc[0])

# %%
plot_resonator.amplitude_and_phase(fs.sweep.resonator, normalize_s21=False);

# %%
fs.state
# Out:
# {u'boffile': u'bb2xpfb14mcr17b_2015_Apr_21_1159.bof',
#  u'delay_estimate': -6.33e-05,
#  u'heterodyne': False}
