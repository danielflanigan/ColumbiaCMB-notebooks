# %%
# %matplotlib inline

# %%
from kid_readout.measurement.io import nc

# %%
ncf = nc.NCFile('/data/detectors/2016-05-04_221947_lo_scan.nc')

# %%
sa = ncf.SweepArray0

# %%
sa.stream_arrays[0].tone_bin.size
# Out:
# 128

# %%
fig, ax = plt.subplots()
for n, s in enumerate(sa.stream_arrays):
    ax.plot(s.frequency_MHz, n * np.ones_like(s.tone_index), '.')

# %%
f = []
for s in sa.stream_arrays:
    f.extend(s.frequency)
f = np.array(sorted(f))

# %%
f.size
# Out:
# 105344

# %%
np.diff(f).max()
# Out:
# 15000.0

# %%
np.diff(f).min()
# Out:
# 4999.9999995231628

# %%
fig, ax = plt.subplots()
ax.plot(f, '.')

# %%
min(f)
# Out:
# 2007937500.0

# %%
max(f)
# Out:
# 2535922500.0

# %%
s21 = sa.s21_raw_stack.mean(axis=-1)

# %%
fig, ax = plt.subplots()
ax.plot(sa.frequency_MHz_stack, 20 * np.log10(np.abs(s21)), '.')

# %%
swp0 = sa.sweep(0)

# %%
fig, ax = plt.subplots()
ax.plot(swp0.frequency, 20 * np.log10(np.abs(swp0.s21_points)), '.')

# %%
len(swp0.streams)
# Out:
# 823

# %%
fig, ax = plt.subplots()
ax.plot(swp0.streams[100].sample_time, np.abs(swp0.streams[100].s21_raw), '.')

# %%
fig, ax = plt.subplots()
ax.plot(sa.stream_arrays[0].s21_raw.real, '.')

# %%
sa.stream_arrays[0].s21_raw.shape
# Out:
# (128, 2)
