# %%
from kid_readout.measurement import core, single, multiple
from kid_readout.roach import interface, calculate
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
frequency = np.linspace(100e6, 200e6, 16)
num_tone_samples = 2**19
adc_sample_rate = 512e6
tone_bin = np.round(frequency / adc_sample_rate * num_tone_samples)
tone_bin
# Out:
# array([ 102400.,  109227.,  116053.,  122880.,  129707.,  136533.,
#         143360.,  150187.,  157013.,  163840.,  170667.,  177493.,
#         184320.,  191147.,  197973.,  204800.])

# %%
s = single.make_stream()

# %%
s.frequency_MHz
# Out:
# 100.0

# %%
s.s21_mean
# Out:
# (0.0063637933651913949+0.015965227274360876j)

# %%
s.s21_mean_error
# Out:
# (0.0079719559196234427+0.0080304147324565308j)

# %%
s.epoch.size
# Out:
# 15625

# %%
plt.plot(s.epoch, np.abs(s.s21), ',')

# %%
plt.plot(s.s21.real, s.s21.imag, ',')

# %%
sa = multiple.make_stream_array()

# %%
[sa.stream(n).frequency_MHz for n in range(sa.tone_index.size)]
# Out:
# [100.0,
#  106.6669921875,
#  113.3330078125,
#  120.0,
#  126.6669921875,
#  133.3330078125,
#  140.0,
#  146.6669921875,
#  153.3330078125,
#  160.0,
#  166.6669921875,
#  173.3330078125,
#  180.0,
#  186.6669921875,
#  193.3330078125,
#  200.0]
