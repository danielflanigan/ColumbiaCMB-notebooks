# %%
from kid_readout.utils import roach_interface
from kid_readout.utils import acquire
from kid_readout.analysis import resonator, plot_resonator

# %%
roach = roach_interface.RoachBaseband()
# Out:
# Loaded ROACH state from /home/data/roach_config.npz

# %%
fit_16 = np.load('/home/data2/resonances/2014-12-06_140825_0813f8_fit_16.npy')

# %%
# Add noise with 5 kHz RMS:
noisy_16 = fit_16 + 5e-3 * np.random.randn(fit_16.size)
noisy_16 - fit_16
# Out:
# array([-0.00158582,  0.0020848 , -0.00806054, -0.00510375,  0.00073877,
#         0.00660836,  0.00094355,  0.00301757, -0.00137148,  0.00759893,
#         0.00151016,  0.00586718, -0.00320349,  0.00587426, -0.00145577,
#        -0.00449884])

# %%
n_samples = 2**21
coarse, fine = acquire.coarse_fit_fine(roach, noisy_16, acquire.offset_integers_31, n_samples)
# Out:
# bank_offset= 0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# writing DRAM bank 1
# writing DRAM bank 2
# writing DRAM bank 3
# detected mcnt overflow
#  None 2137463 0 16384 0 96 2137463
# bank_offset=
#  0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# writing DRAM bank 1
# writing DRAM bank 2
# writing DRAM bank 3
# detected mcnt overflow
#  None 1088887 0 16384 0 176 1088887

# %%
cr = acquire.fit_sweep_data(coarse)
fr = acquire.fit_sweep_data(fine)

# %%
figs = [plot_resonator.amplitude_and_phase(r, normalize_s21=True) for r in cr]

# %%
figs = [plot_resonator.amplitude_and_phase(r, normalize_s21=True) for r in fr]

# %%
plt.semilogy([r.f_0 for r in fr], [r.a for r in fr],'.')

# %% [markdown]
# acquire.fit_sweep_data was not using errors for these fits:

# %%
plt.semilogy([r.f_0 for r in fr], [r.result.redchi for r in fr], '.')

# %%
[r.result.success for r in fr]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]
