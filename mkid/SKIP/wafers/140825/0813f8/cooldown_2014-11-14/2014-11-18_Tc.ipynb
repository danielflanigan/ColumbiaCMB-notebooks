# %%
from kid_readout.utils import readoutnc
from kid_readout.utils import starcryo_temps
# Out:
# updated file list

# %%
nc = readoutnc.ReadoutNetCDF('/home/data2/2014-11-17_220103.nc')

# %%
nc.timestreams

# %%
nc.timestream_20141117220107.data.shape
# Out:
# (657, 8192)

# %%
epoch = nc.timestream_20141117220107.epoch

# %%
epoch.shape
# Out:
# (657,)

# %%
plt.plot((epoch[:50] - epoch[0]) / 60, '.')

# %%
data = nc.timestream_20141117220107.data

# %% [markdown]
# Something is wrong with data block 0:

# %%
for n in range(0, data.shape[0], 20):
    plt.plot(abs(data[n]), label=str(n))
#plt.legend(loc='best')

# %%
means = data.mean(axis=1)

# %%
means.shape
# Out:
# (657,)

# %%
plt.plot(epoch, means.imag)
plt.plot(epoch, means.real)

# %%
package, package2, load, load2 = starcryo_temps.get_temperatures_at(epoch)

# %%
plt.plot((epoch-epoch[0])/3600, package)

# %%
plt.plot(package, abs(means))

# %%
T_c = package[np.argmax(abs(np.diff(means)))]
T_c
# Out:
# 1.3914347970907688
