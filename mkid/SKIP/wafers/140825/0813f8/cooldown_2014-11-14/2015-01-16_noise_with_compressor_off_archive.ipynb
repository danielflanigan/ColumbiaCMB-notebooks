# %% [markdown]
# Why are some, but not all, of the noise levels so different? Is this an issue with the calculation of $d S_{21} / d f$? Is the amplifier actually heating up?

# %%
from glob import glob
from kid_readout.analysis import archive
from notebooks.library import dataframe
plt.rcParams['font.size'] = 11
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
off = archive.build_simple_archive(glob('/home/data/pkl/2015-01-16_*_compressor_off_noise.pkl'))

# %%
indices = sorted(set(off.resonator_index))

# %%
[dataframe.plot_sweeps(off, n) for n in indices];

# %%
[dataframe.plot_sweeps_IQ(off, n) for n in indices];

# %%
[dataframe.plot_pca_noise(off, n) for n in indices];
