# %% [markdown]
# This is the data set Glenn used to do the previous NEP analysis.

# %%
from kid_readout.analysis import archive
plt.rcParams['font.size'] = 11
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
df = archive.load_archive('/home/gjones/2015-01-21-dfr39-temp.npy')
df.shape
# Out:
# (3666, 107)

# %%
#df = archive.get_con

# %%
print([column for column in df.columns])
# Out:
# ['index', 'A_mag', 'A_mag_err', 'A_phase', 'A_phase_err', 'Q', 'Q_e_imag', 'Q_e_imag_err', 'Q_e_real', 'Q_e_real_err', 'Q_err', 'Q_i', 'a', 'a_err', 'adc_sampling_freq_MHz', 'amplifier_noise', 'atten', 'chip_name', 'dac_chain_gain', 'deglitch_threshold', 'deglitch_window', 'delay', 'delay_err', 'device_noise', 'end_temp', 'experiment_description', 'experiment_info', 'f_0', 'f_0_err', 'f_phi', 'f_phi_err', 'folded_projected_timeseries', 'freqs_coarse', 'is_dark', 'low_pass_normalized_timeseries', 'low_pass_projected_timeseries', 'low_pass_timestep', 'mmw_atten_turns', 'mmw_mod_duty_cycle', 'mmw_mod_freq', 'mmw_mod_phase', 'nfft', 'noise_measurement_freq_MHz', 'normalized_ds21_df_at_meas_freq', 'normalized_model_s21_at_meas_freq', 'normalized_model_s21_at_resonance', 'normalized_timeseries_mean', 'optical_state', 'pca_S', 'pca_angles', 'pca_eigvals', 'pca_eigvects', 'pca_freq', 'pca_piq', 'phi', 'phi_err', 'pii_coarse', 'power_dbm', 'prr_coarse', 'resonator_id', 'resonator_index', 'rou
# ...

# %%
plt.plot(df.sweep_epoch, df.sweep_primary_package_temperature, '.')
plt.ylim(0.15, 0.20)
# Out:
# (0.15, 0.2)

# %%
temperature_mask = ((0.183 - 0.005 < df.sweep_primary_package_temperature) &
                    (df.sweep_primary_package_temperature < 0.183 + 0.005))
constant = df[temperature_mask]

# %%
#constant_temp_mask = 

plt.semilogy(constant.sweep_primary_package_temperature,
             constant.device_noise - constant.amplifier_noise, '.')

# %%
plt.plot(constant.zbd_voltage, constant.zbd_power, '.')
plt.plot(constant.zbd_voltage, constant.zbd_voltage / constant.zbd_volts_to_watts, '.')

# %%
plt.plot(constant.zbd_voltage, constant.zbd_voltage / constant.zbd_volts_to_watts - constant.zbd_power, '.')
plt.ylim(-0.0001, 0.0001)
# Out:
# (-0.0001, 0.0001)

# %% [markdown]
# Not sure what's going on here...

# %%
constant.shape
# Out:
# (2507, 107)

# %%
good = constant[constant.zbd_power == constant.zbd_voltage / constant.zbd_volts_to_watts]
good.shape
# Out:
# (1208, 107)

# %%
plt.plot(1e6 * good.zbd_power, -1 / (good.dpdf * good.f_0), '.')

# %%
plt.plot(1e6 * good.zbd_power, 1e6 * (good.f_0 / good.f_0_max - 1), '.')
plt.ylim(-1000, 0)
# Out:
# (-1000, 0)
