# %%
# %matplotlib inline

# %%
from kid_readout.measurement.io import npy
from kid_readout.measurement import plot_basic

# %%
npd = npy.NumpyDirectory('/data/detectors/2017-02-14_121353_uncontrolled.npd/')

# %%
npd.node_names()
# Out:
# ['SingleSweepStream0',
#  'SingleSweep1',
#  'SingleStream2',
#  'ADCSnap3',
#  'SingleSweepStream4',
#  'SingleSweep5',
#  'SingleStream6',
#  'ADCSnap7',
#  'SingleSweepStream8',
#  'SingleSweep9',
#  'SingleStream10',
#  'ADCSnap11',
#  'SingleSweepStream12',
#  'SingleSweep13',
#  'SingleStream14',
#  'ADCSnap15',
#  'SingleSweepStream16',
#  'SingleSweep17',
#  'SingleStream18',
#  'ADCSnap19']

# %%
all_sss = [npd.read(name) for name in npd.node_names() if name.startswith('SingleSweepStream')]

# %%
all_snap = [npd.read(name) for name in npd.node_names() if name.startswith('ADCSnap')]

# %%
[(snap.x.ptp(), snap.y.ptp()) for snap in all_snap]
# Out:
# [(24.0, 27.0), (26.0, 24.0), (25.0, 25.0), (27.0, 23.0), (9.0, 9.0)]

# %%
sss = all_sss[0]
fig, ax = plt.subplots()
plot_basic.sss_complex_plane(sss, ax)
ax.set_title(r'$Q_i = {:.0f}, \qquad Q_c = {:.0f}$'.format(sss.resonator.Q_i, sss.resonator.Q_e_real))

# %%
sss = all_sss[1]
fig, ax = plt.subplots()
plot_basic.sss_complex_plane(sss, ax)
ax.set_title(r'$Q_i = {:.0f}, \qquad Q_c = {:.0f}$'.format(sss.resonator.Q_i, sss.resonator.Q_e_real))

# %%
sss = all_sss[2]
fig, ax = plt.subplots()
plot_basic.sss_complex_plane(sss, ax)
ax.set_title(r'$Q_i = {:.0f}, \qquad Q_c = {:.0f}$'.format(sss.resonator.Q_i, sss.resonator.Q_e_real))

# %%
sss = all_sss[3]
fig, ax = plt.subplots()
plot_basic.sss_complex_plane(sss, ax)
ax.set_title(r'$Q_i = {:.0f}, \qquad Q_c = {:.0f}$'.format(sss.resonator.Q_i, sss.resonator.Q_e_real))

# %%
sss = all_sss[4]
fig, ax = plt.subplots()
plot_basic.sss_complex_plane(sss, ax)
ax.set_title(r'$Q_i = {:.0f}, \qquad Q_c = {:.0f}$'.format(sss.resonator.Q_i, sss.resonator.Q_e_real))

# %%
sss = all_sss[0]
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.plot(sss.S_frequency, sss.S_xx, label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, label='$S_{yy}$')
ax.legend();

# %%
sss = all_sss[1]
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.plot(sss.S_frequency, sss.S_xx, label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, label='$S_{yy}$')
ax.legend();

# %%
sss = all_sss[2]
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.plot(sss.S_frequency, sss.S_xx, label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, label='$S_{yy}$')
ax.legend();

# %%
sss = all_sss[3]
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.plot(sss.S_frequency, sss.S_xx, label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, label='$S_{yy}$')
ax.legend();

# %%
sss = all_sss[4]
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.plot(sss.S_frequency, sss.S_xx, label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, label='$S_{yy}$')
ax.legend();
