# %%
# %matplotlib inline

# %%
mpl.get_configdir()
# Out:
# u'/home/flanigan/.config/matplotlib'

# %%
mpl.matplotlib_fname()
# Out:
# u'/home/flanigan/.config/matplotlib/matplotlibrc'

# %%
plt.rcParams['backend']
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
plt.rcParams['figure.dpi']
# Out:
# 300.0

# %%
plt.rcParams['savefig.dpi']
# Out:
# 300.0

# %%
fig, ax = plt.subplots()
ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('$Q_i$')
ax.set_title('title')
ax.plot(1e-3 * np.random.randn(10))
ax.plot(1e-3 * np.random.randn(10), '.')
