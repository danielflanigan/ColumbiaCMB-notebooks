# %%
# %matplotlib inline

# %%
from kid_readout.measurement.io import npy
from kid_readout.measurement import plot_basic

# %%
npd = npy.NumpyDirectory('/data/detectors/2017-03-06_154206_preliminary.npd/')

# %%
npd.node_names()
# Out:
# ['SingleSweep0',
#  'SingleSweepStream1',
#  'ADCSnap2',
#  'SingleSweep3',
#  'SingleSweepStream4',
#  'ADCSnap5']

# %%
swp24 = npd.SingleSweep0
sss24 = npd.SingleSweepStream1
snap24 = npd.ADCSnap2
swp30 = npd.SingleSweep3
sss30 = npd.SingleSweepStream4
snap30 = npd.ADCSnap5

# %%
snap24.x.ptp()
# Out:
# 124.0

# %%
snap30.x.ptp()
# Out:
# 67.0

# %%
fig, ax = plt.subplots()
plot_basic.resonator_amplitude(swp24.resonator, ax)
plot_basic.resonator_amplitude(sss24.resonator, ax);

# %%
fig, ax = plt.subplots()
plot_basic.sss_complex_plane(sss24, ax)

# %%
fig, ax = plt.subplots()
plot_basic.sss_complex_plane(sss30, ax)

# %%
sss24.resonator.Q_i
# Out:
# 762.59995751818099

# %%
sss30.resonator.Q_i
# Out:
# 834.98636150693062

# %%
sss24.resonator.Q_e
# Out:
# (6687.4990603051028-3618.005468942225j)

# %%
sss30.resonator.Q_e
# Out:
# (6822.5772680606324-3341.2224517446011j)
