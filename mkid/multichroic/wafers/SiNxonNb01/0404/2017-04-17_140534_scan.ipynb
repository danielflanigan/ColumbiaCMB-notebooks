# %%
# %matplotlib inline

# %%
from kid_readout.measurement.io import npy

# %%
figure_directory = '/home/flanigan/temp/'

# %%
npd = npy.NumpyDirectory('/data/detectors/2017-04-17_140534_scan.npd/')

# %%
scan = npd.Scan0
snaps = [npd.read(name) for name in npd.node_names() if name.startswith('ADCSnap')]

# %%
fig, ax = plt.subplots()
for snap in snaps:
    ax.plot(snap.x.ptp(), snap.y.ptp(), '.')

# %%
sweep.stream_arrays[0].roach_state
# Out:
# StateDict({u'boffile': u'iq2xpfb14mcr11_2016_Jun_30_1301.bof', u'modulation_output': 0, u'modulation_rate': 0, u'fft_shift_register': 1048448, u'num_tone_samples': 4096, u'bank': 0, u'num_filterbank_channels': 16384, u'loopback': False, u'lo_frequency': 3445000000.0, u'adc_sample_rate': 512000000.0, u'waveform_normalization': 0.005859375, u'hardware_delay_samples': -16025.6, u'num_tones': 32, u'debug_register': 0, u'reference_sequence_number': -1, u'dac_attenuation': 0.0, u'heterodyne': True})

# %%
fig, ax = plt.subplots()
ax.set_xlabel('frequency / MHz')
ax.set_ylabel('$|S_{21}|^2$ / dB')

for sweep in scan.sweep_arrays:
    ax.plot(sweep.frequency_MHz, 20 * np.log10(np.abs(sweep.s21_point)), '-k')

# %%
fig, ax = plt.subplots()
ax.plot(scan.sweep_arrays[0].s21_point.real, scan.sweep_arrays[0].s21_point.imag, '.')
