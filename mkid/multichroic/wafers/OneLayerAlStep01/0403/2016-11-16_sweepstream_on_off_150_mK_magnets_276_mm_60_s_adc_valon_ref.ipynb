# %%
# %matplotlib inline

# %%
from kid_readout.measurement.io import npy
from kid_readout.measurement import temperature
from kid_readout.measurement import plot_basic
from kid_readout.analysis.resonator import plot_resonator

# %%
npd = npy.NumpyDirectory('/data/detectors/2016-11-16_141202_sweep_stream_on_off_locked/')

# %%
all_sss = [npd.read(name) for name in npd.node_names() if name.startswith('SingleSweepStream')]

# %%
num_channels = 7
sss_dict = {}
for channel in range(num_channels):
    sss_dict[channel] = [sss for sss in all_sss if sss.state.lo_index == channel]

# %%
num_attenuations = 2  # len(all_sss) / num_channels

# %%
channel = 0
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, sss in enumerate(sss_dict[channel]):
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
channel = 1
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, sss in enumerate(sss_dict[channel]):
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
channel = 2
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, sss in enumerate(sss_dict[channel]):
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
channel = 3
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, sss in enumerate(sss_dict[channel]):
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
channel = 3
fig, ax = plt.subplots()
for sss in sss_dict[channel]:
    plot_resonator.amplitude(ax, sss.resonator)
    print("Qi: {:.0f}; Qc: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real))
# Out:
# Qi: 67939; Qc: 213134
# Qi: 113569; Qc: 188265

# %%
channel = 4
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, sss in enumerate(sss_dict[channel]):
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
channel = 4
fig, ax = plt.subplots()
for sss in sss_dict[channel]:
    plot_resonator.amplitude(ax, sss.resonator)
    print("Qi: {:.0f}; Qc: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real))
# Out:
# Qi: 81122; Qc: 59317
# Qi: 161375; Qc: 50048

# %%
channel = 5
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, sss in enumerate(sss_dict[channel]):
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
channel = 5
fig, ax = plt.subplots()
for sss in sss_dict[channel]:
    plot_resonator.amplitude(ax, sss.resonator)
    print("Qi: {:.0f}; Qc: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real))
# Out:
# Qi: 74193; Qc: 30071
# Qi: 116602; Qc: 28241

# %%
channel = 6
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, sss in enumerate(sss_dict[channel]):
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
channel = 6
fig, ax = plt.subplots()
for sss in sss_dict[channel]:
    plot_resonator.amplitude(ax, sss.resonator)
    print("Qi: {:.0f}; Qc: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real))
# Out:
# Qi: 70854; Qc: 29137
# Qi: 104503; Qc: 28285

# %%
f_scale = 1e-9
Qi_color = 'blue'
Qc_color = 'green'
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'black', 'gray']

# %%
attenuation_index = 1
fig, ax = plt.subplots()
sssl = [sss_list[attenuation_index] for sss_list in sss_dict.values()]
ax.plot([f_scale * sss.resonator.f_0 for sss in sssl],
        [sss.resonator.Q_i for sss in sssl],
        'o', color=Qi_color, label='$Q_i$')
ax.plot([f_scale * sss.resonator.f_0 for sss in sssl],
        [sss.resonator.Q_e_real for sss in sssl],
        's', color=Qc_color, label='$Q_c$')

ax.set_xlabel('frequency [GHz]')
ax.set_ylabel('quality factor')
ax.legend(loc='upper center', numpoints=1)
ax.set_xlim(1.9, 4.1);

# %%
attenuation_index = 0

fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('spectral density / Hz$^{-1}$')

for channel, sssl in sss_dict.items():
    sss = sssl[attenuation_index]
    sss.set_S(binned=True)
    ax.plot(sss.S_frequency, sss.S_xx, color=colors[channel])
    ax.plot(sss.S_frequency, sss.S_yy, color=colors[channel])

# %%
attenuation_index = 1

fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('spectral density / Hz$^{-1}$')

for channel, sssl in sss_dict.items():
    sss = sssl[attenuation_index]
    sss.set_S(binned=True)
    ax.plot(sss.S_frequency, sss.S_xx, color=colors[channel])
    ax.plot(sss.S_frequency, sss.S_yy, color=colors[channel])

# %%
attenuation_index = 1
channel = 0
sss = sss_dict[channel][attenuation_index]
sss.set_S(binned=False)
fig, ax = plt.subplots()
ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('spectral density / Hz$^{-1}$')
ax.set_yscale('log')
ax.set_xticks([0, 60, 120, 180, 240, 300])

for f in [60, 120, 180, 240]:
    ax.axvline(f, color='gray')
ax.plot(sss.S_frequency, sss.S_xx, color='k', label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, color='r', label='$S_{yy}$')
ax.legend(loc='upper right', ncol=1, fontsize='xx-small')

ax.set_xlim(0, 300);

# %%
[1e-9 * sss.stream.roach_state.lo_frequency for sss in all_sss]
# Out:
# [2.2438000000000002,
#  2.2438000000000002,
#  2.3158000000000003,
#  2.3158000000000003,
#  2.4725,
#  2.4725,
#  3.3023000000000002,
#  3.3023000000000002,
#  3.3673,
#  3.3673,
#  3.492600000000001,
#  3.492600000000001,
#  3.5134000000000003,
#  3.5134000000000003]
