# %%
# %matplotlib inline
from kid_readout.measurement.io import npy
from kid_readout.measurement import temperature, plot_basic
from kid_readout.analysis.resonator.plot_resonator import amplitude
from kid_readout.analysis.timeseries import iqnoise

# %%
npd = npy.NumpyDirectory('/data/detectors/2016-11-16_154421_sweep_stream_simultaneous_locked/')

# %%
npd.node_names()
# Out:
# ['SweepStreamArray0',
#  'ADCSnap1',
#  'SweepStreamArray2',
#  'ADCSnap3',
#  'SweepStreamArray4',
#  'ADCSnap5',
#  'SweepStreamArray6',
#  'ADCSnap7']

# %%
all_ssa = [npd.read(name) for name in npd.node_names() if name.startswith('SweepStreamArray')]

# %%
num_attenuations = 2
low_ssa = all_ssa[:num_attenuations]
high_ssa = all_ssa[num_attenuations:]

# %%
all_snaps = [npd.read(name) for name in npd.node_names() if name.startswith('ADCSnap')]

# %%
[(snap.x.ptp(), snap.y.ptp()) for snap in all_snaps]
# Out:
# [(88.0, 99.0), (32.0, 33.0), (34.0, 34.0), (16.0, 17.0)]

# %%
number = 0
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, ssa in enumerate(low_ssa):
    sss = ssa[number]
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
number = 1
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, ssa in enumerate(low_ssa):
    sss = ssa[number]
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
number = 2
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, ssa in enumerate(low_ssa):
    sss = ssa[number]
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %% [markdown]
# Number 3 is a dummy channel

# %%
number = 0
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, ssa in enumerate(high_ssa):
    sss = ssa[number]
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
number = 1
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, ssa in enumerate(high_ssa):
    sss = ssa[number]
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
number = 2
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, ssa in enumerate(high_ssa):
    sss = ssa[number]
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
number = 3
fig, axes = plt.subplots(2, num_attenuations, figsize=(2 * num_attenuations, 4))
for n, ssa in enumerate(high_ssa):
    sss = ssa[number]
    full_ax = axes[0, n]
    full_ax.set_title("$Q_i$: {:.0f}; $Q_c$: {:.0f}".format(sss.resonator.Q_i, sss.resonator.Q_e_real), fontsize=6)
    plot_basic.sss_complex_plane(sss, full_ax)
    full_ax.tick_params(labelsize=5)
    zoom_ax = axes[1, n]
    plot_basic.sss_complex_plane(sss, zoom_ax, zoom=True)
    zoom_ax.tick_params(labelsize=5)

# %%
f_scale = 1e-9
Qi_color = 'blue'
Qc_color = 'green'
colors = ['blue', 'green', 'red', 'gray', 'cyan', 'magenta', 'yellow', 'black']

# %%
attenuation_index = 1
fig, ax = plt.subplots()
for lh_index, ssa in enumerate([low_ssa[attenuation_index], high_ssa[attenuation_index]]):
    for number in range(ssa.num_channels):
        if lh_index != 0 or number != 3:
            ax.plot(f_scale * ssa[number].resonator.f_0,
                    ssa[number].resonator.Q_i,
                    'o', color=Qi_color, label='$Q_i$')
            ax.plot(f_scale * ssa[number].resonator.f_0,
                    ssa[number].resonator.Q_e_real,
                    's', color=Qc_color, label='$Q_c$')

ax.set_xlabel('frequency [GHz]')
ax.set_ylabel('quality factor')
#ax.legend(loc='upper center', numpoints=1)
#ax.set_xlim(1.9, 4.1)
#ax.set_ylim(0, 2e5)

# %%
Sxx_linewidth = 0.5
Syy_linewidth = 0.3

# %%
attenuation_index = 0

fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('frequency / Hz')
ax.set_ylabel('spectral density / Hz$^{-1}$')

for lh_index, ssa in enumerate([low_ssa[attenuation_index], high_ssa[attenuation_index]]):
    for number in range(ssa.num_channels):
        if lh_index != 0 or number != 3:
            ax.plot(ssa[number].S_frequency, ssa[number].S_xx,
                    color=colors[number + 4 * lh_index], linewidth=Sxx_linewidth)
            ax.plot(ssa[number].S_frequency, ssa[number].S_yy,
                    color=colors[number + 4 * lh_index], linewidth=Syy_linewidth)

# %%
attenuation_index = 1

fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('frequency / Hz')
ax.set_ylabel('spectral density / Hz$^{-1}$')

for lh_index, ssa in enumerate([low_ssa[attenuation_index], high_ssa[attenuation_index]]):
    for number in range(ssa.num_channels):
        if lh_index != 0 or number != 3:
            ax.plot(ssa[number].S_frequency, ssa[number].S_xx,
                    color=colors[number + 4 * lh_index], linewidth=Sxx_linewidth)
            ax.plot(ssa[number].S_frequency, ssa[number].S_yy,
                    color=colors[number + 4 * lh_index], linewidth=Syy_linewidth)

# %%
num_channels = 3
ssa_list = low_ssa
fig, axes = plt.subplots(1, num_channels, figsize=(2 * num_channels, 2))
for channel in range(num_channels):
    ax = axes[channel]
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.tick_params(labelsize=4)
    ax.set_xlim(0.1, 2e4)
    ax.set_ylim(1e-19, 1e-15)
    for index, ssa in enumerate(ssa_list):
        sss = ssa[channel]
        sss.set_S(window=plt.mlab.window_hanning)
        ax.plot(sss.S_frequency, sss.S_xx, color=colors[index],
                label='{:.1f} dB'.format(sss.stream.roach_state.dac_attenuation),
                linewidth=Sxx_linewidth)
        ax.plot(sss.S_frequency, sss.S_yy, color=colors[index],
                linewidth=Syy_linewidth)
    ax.set_title('{:.0f} MHz'.format(sss.stream.frequency_MHz), fontsize=5)
axes[0].legend(loc='lower left', bbox_to_anchor=(0, -0.4), ncol=len(ssa_list))
axes[-1].set_xlabel('frequency / Hz')
axes[0].set_ylabel('spectral density / Hz$^{-1}$')

fig.savefig('/home/flanigan/temp/simultaneous_150_mK_Sxx_and_Syy_low_band.pdf')

# %%
num_channels = 3
ssa_list = low_ssa
fig, axes = plt.subplots(1, num_channels, figsize=(2 * num_channels, 2))
for channel in range(num_channels):
    ax = axes[channel]
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.tick_params(labelsize=4)
    ax.set_xlim(0.1, 2e4)
    ax.set_ylim(1e-19, 1e-15)
    for index, ssa in enumerate(ssa_list):
        sss = ssa[channel]
        sss.set_S(window=plt.mlab.window_hanning)
        ax.plot(sss.S_frequency, sss.S_xx - sss.S_yy, color=colors[index],
                label='{:.1f} dB'.format(sss.stream.roach_state.dac_attenuation))
    ax.set_title('{:.0f} MHz'.format(sss.stream.frequency_MHz), fontsize=5)
axes[0].legend(loc='lower left', bbox_to_anchor=(0, -0.4), ncol=len(ssa_list))
axes[-1].set_xlabel('frequency / Hz')
axes[0].set_ylabel('$(S_{xx} - S_{yy}) \; / \; \mathrm{Hz}^{-1}$')

fig.savefig('/home/flanigan/temp/simultaneous_150_mK_Sxx-Syy_low_band.pdf')

# %%
num_channels = 4
ssa_list = high_ssa
fig, axes = plt.subplots(1, num_channels, figsize=(2 * num_channels, 2))
for channel in range(num_channels):
    ax = axes[channel]
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.tick_params(labelsize=4)
    ax.set_xlim(0.1, 2e4)
    ax.set_ylim(1e-20, 1e-15)
    for index, ssa in enumerate(ssa_list):
        sss = ssa[channel]
        sss.set_S(window=plt.mlab.window_hanning)
        ax.plot(sss.S_frequency, sss.S_xx, color=colors[index],
                label='{:.1f} dB'.format(sss.stream.roach_state.dac_attenuation),
                linewidth=Sxx_linewidth)
        ax.plot(sss.S_frequency, sss.S_yy, color=colors[index],
                linewidth=Syy_linewidth)
    ax.set_title('{:.0f} MHz'.format(sss.stream.frequency_MHz), fontsize=5)
axes[0].legend(loc='lower left', bbox_to_anchor=(0, -0.4), ncol=len(ssa_list))
axes[-1].set_xlabel('frequency / Hz')
axes[0].set_ylabel('spectral density / Hz$^{-1}$')

fig.savefig('/home/flanigan/temp/simultaneous_150_mK_Sxx_and_Syy_high_band.pdf')

# %%
num_channels = 4
ssa_list = high_ssa
fig, axes = plt.subplots(1, num_channels, figsize=(2 * num_channels, 2))
for channel in range(num_channels):
    ax = axes[channel]
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.tick_params(labelsize=4)
    ax.set_xlim(0.1, 2e4)
    ax.set_ylim(1e-19, 1e-16)
    for index, ssa in enumerate(ssa_list):
        sss = ssa[channel]
        sss.set_S(window=plt.mlab.window_hanning)
        ax.plot(sss.S_frequency, sss.S_xx - sss.S_yy, color=colors[index],
                label='{:.1f} dB'.format(sss.stream.roach_state.dac_attenuation))
    ax.plot(sss.S_frequency, 6e-18 * sss.S_frequency**(-1/2), '--k', label='$f^{-1/2}$')
    ax.set_title('{:.0f} MHz'.format(sss.stream.frequency_MHz), fontsize=5)
axes[0].legend(loc='lower left', bbox_to_anchor=(0, -0.4), ncol=len(ssa_list) + 1)
axes[-1].set_xlabel('frequency / Hz')
axes[0].set_ylabel('$(S_{xx} - S_{yy}) \; / \; \mathrm{Hz}^{-1}$')

fig.savefig('/home/flanigan/temp/simultaneous_150_mK_Sxx-Syy_high_band.pdf')
