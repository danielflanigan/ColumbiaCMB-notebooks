# %%
from __future__ import division, print_function
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import pandas as pd
# %matplotlib inline

from kid_readout.measurement.io import npy
from kid_readout.measurement import basic, plot_basic

# %%
npd = npy.NumpyDirectory('/data/readout/2017-12-14_172545_mmw_test.npd/')

# %%
npd.node_names()
# Out:
# ['SingleSweep0']

# %%
initial = npd.SingleSweep0

# %%
fig, ax = plt.subplots()
plot_basic.resonator_complex_plane(axis=ax, resonator=initial.resonator);
