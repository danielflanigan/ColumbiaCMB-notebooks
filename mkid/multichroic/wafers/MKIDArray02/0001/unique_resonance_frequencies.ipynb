# %%
from __future__ import division, print_function
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
f_r = np.load('unique_resonance_frequencies.npy')

# %%
1e-6 * f_r
# Out:
# array([ 1919.69432779,  2062.5021086 ,  2335.40458665,  2396.46803224,
#         2591.00377748,  2676.49488674,  2757.56902622,  2778.68139395,
#         2792.43786231,  2806.28495819,  2807.41539914,  2816.12867816,
#         2881.44454812,  2921.42028171,  2955.64281538,  2958.39476355,
#         2961.17337062,  2979.83148276,  2998.28496302,  3001.22215264,
#         3061.67203117,  3063.34899769,  3065.77506332,  3078.08791326,
#         3081.02305437,  3084.91859403,  3091.41646027,  3092.7501607 ,
#         3096.55058871,  3097.31788627,  3122.20705902,  3126.84536213,
#         3132.52831775,  3187.60525467,  3208.60183053,  3224.05041181,
#         3229.46615086,  3248.04082943,  3263.37240623,  3268.226507  ,
#         3277.23105974,  3278.94716223,  3316.56809326,  3325.5516192 ,
#         3326.84158561,  3347.24341515,  3370.56806089,  3405.28503563,
#         3409.68462061,  3420.60251965,  3433.27430647,  3450.44746311,
#         3470.37609203,  3922.26758406])

# %%
f_low = f_r[f_r < 2.5e9]

# %%
fig, ax = plt.subplots()
#ax.grid()
ax.plot(1e-6 * f_r, '.')
edge_color = 'C1'
edges = (1900, 2300, 2500, 2700, 2850, 3025, 3150, 3290, 3490)
for edge in edges:
    ax.axhline(edge, color=edge_color)

# %%
counts, bins = np.histogram(1e-6 * f_r, bins=edges)

# %%
bins
# Out:
# array([1900, 2300, 2500, 2700, 2850, 3025, 3150, 3290, 3490])

# %%
counts
# Out:
# array([ 2,  2,  2,  6,  8, 13,  9, 11])
