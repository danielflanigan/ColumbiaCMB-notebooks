# %%
# %matplotlib inline

# %%
plt.rcParams['font.size'] = 8

# %%
from kid_readout.measurement.io import nc

# %%
ncf = nc.NCFile('/data/readout/2016-07-13_160639_ambient.nc')

# %%
ncf.node_names()
# Out:
# [u'SweepArray0',
#  u'SweepStreamArray1',
#  u'ADCSnap2',
#  u'SweepArray3',
#  u'SweepStreamArray4',
#  u'ADCSnap5',
#  u'SweepArray6',
#  u'SweepStreamArray7',
#  u'ADCSnap8',
#  u'SweepArray9',
#  u'SweepStreamArray10',
#  u'ADCSnap11',
#  u'SweepArray12',
#  u'SweepStreamArray13',
#  u'ADCSnap14']

# %%
ssas = [ncf.read(name) for name in ncf.node_names() if name.startswith('SweepStreamArray')]

# %%
from collections import namedtuple
ResonatorData = namedtuple('ResonatorData', field_names=['f_data', 's21_data',
                                                         'f_model', 's21_model',
                                                         'f_r', 's21_r'])

def extract(resonator, normalize, num_model_points):
    f_data = resonator.frequency.copy()
    s21_data = resonator.data.copy()
    f_model = np.linspace(f_data.min(), f_data.max(), num_model_points)
    s21_model = resonator.model.eval(params=resonator.current_params, f=f_model)
    f_r = resonator.f_0
    s21_r = resonator.model.eval(params=resonator.current_params, f=f_r)
    if normalize:
        s21_data = resonator.remove_background(frequency=f_data, s21_raw=s21_data)
        s21_model = resonator.remove_background(frequency=f_model, s21_raw=s21_model)
        s21_r = resonator.remove_background(frequency=f_r, s21_raw=s21_r)
    return ResonatorData(f_data, s21_data, f_model, s21_model, f_r, s21_r)

    
def amplitude(axis, resonator, normalize=False, num_model_points=1000, f_scale=1e-6, three_ticks=True):
    rd = extract(resonator, normalize, num_model_points)
    ax.plot(f_scale * rd.f_data, 20 * np.log10(np.abs(rd.s21_data)), '.b', markersize=2)
    ax.plot(f_scale * rd.f_model, 20 * np.log10(np.abs(rd.s21_model)), '-', color='brown')
    ax.plot(f_scale * rd.f_r, 20 * np.log10(np.abs(rd.s21_r)), '.', color='brown', markersize=3)
    if three_ticks:
        ax.set_xticks(f_scale * np.array([rd.f_data.min(), rd.f_r, rd.f_data.max()]))

# %% [markdown]
# # Temperature

# %%
fig, ax = plt.subplots()
ax.plot([(sss.stream_array.epoch - ssas[0].stream_array.epoch) / 60 for sss in ssas],
        [sss.state.temperature.package for sss in ssas],
        '.b')
ax.set_xlabel('elapsed time [minutes]')
ax.set_ylabel('package temperature [K]');

# %% [markdown]
# # Sweep data for three resonators

# %%
channel_index = 0

fig, ax = plt.subplots()
ax.set_xlabel('frequency [MHz]')
ax.set_ylabel('$|S_{21}|$ [dB]')

for ssa in ssas[2:4]:
    ss = ssa[channel_index]
    amplitude(ax, ss.sweep.resonator, normalize=True)

# %%
channel_index = 1

fig, ax = plt.subplots()
ax.set_xlabel('frequency [MHz]')
ax.set_ylabel('$|S_{21}|$ [dB]')

for ssa in ssas[3:]:
    ss = ssa[channel_index]
    amplitude(ax, ss.sweep.resonator, normalize=True)

# %%
channel_index = 2

fig, ax = plt.subplots()
ax.set_xlabel('frequency [MHz]')
ax.set_ylabel('$|S_{21}|$ [dB]')

for ssa in ssas[3:]:
    ss = ssa[channel_index]
    amplitude(ax, ss.sweep.resonator, normalize=True)

# %% [markdown]
# # Data selection

# %%
good_ssas = ssas[3:]

# %% [markdown]
# # Dummy channel

# %%
channel_index = 3

fig, ax = plt.subplots()
ax.set_xlabel('frequency [MHz]')
ax.set_ylabel('$|S_{21}|$ [dB]')

for ssa in ssas:
    ss = ssa[channel_index]
    amplitude(ax, ss.sweep.resonator)

# %% [markdown]
# # Quality factors

# %%
fig, ax = plt.subplots()

for ssa in good_ssas:
    f = np.array([1e-6 * ssa[n].sweep.resonator.f_0 for n in range(ssa.num_channels-1)])
    Qi = np.array([ssa[n].sweep.resonator.Q_i for n in range(ssa.num_channels-1)])
    Qc = np.array([ssa[n].sweep.resonator.Q_e_real for n in range(ssa.num_channels-1)])
    ax.plot(f, Qi, marker='o', linestyle='none', 
            label="{} dB".format(ssa.stream_array.roach_state.dac_attenuation))

ax.set_xlabel('frequency [MHz]')
ax.set_ylabel('$Q_i$')
ax.set_xlim(70, 170)
ax.set_ylim(0, 1.5e5)
ax.legend(loc='upper left', fontsize='xx-small')

# %%
fig, ax = plt.subplots()

for ssa in good_ssas:
    f = np.array([1e-6 * ssa[n].sweep.resonator.f_0 for n in range(ssa.num_channels-1)])
    Qc = np.array([ssa[n].sweep.resonator.Q_e_real for n in range(ssa.num_channels-1)])
    ax.plot(f, Qc, marker='o', linestyle='none', 
            label="{} dB".format(ssa.stream_array.roach_state.dac_attenuation))

ax.set_xlabel('frequency [MHz]')
ax.set_ylabel('$Q_c$')
ax.set_xlim(70, 170)
ax.set_ylim(0, 1.5e5)
ax.legend(loc='lower right', fontsize='xx-small')

# %% [markdown]
# # Noise

# %%
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')

channel_index = 0
atten_index = 4

sss = ssas[atten_index][channel_index]
ax.plot(sss.S_frequency, sss.S_xx, label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, label='$S_{yy}$')

ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('spectral density [Hz$^{-1}$]')
ax.set_title('{:.1f} MHz'.format(1e-6 * sss.sweep.resonator.f_0))
ax.legend(loc='best', fontsize='small');

# %%
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')

channel_index = 1
atten_index = 4

sss = ssas[atten_index][channel_index]
ax.plot(sss.S_frequency, sss.S_xx, label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, label='$S_{yy}$')

ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('spectral density [Hz$^{-1}$]')
ax.set_title('{:.1f} MHz'.format(1e-6 * sss.sweep.resonator.f_0))
ax.legend(loc='best', fontsize='small');

# %%
fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')

channel_index = 2
atten_index = 4

sss = ssas[atten_index][channel_index]
ax.plot(sss.S_frequency, sss.S_xx, label='$S_{xx}$')
ax.plot(sss.S_frequency, sss.S_yy, label='$S_{yy}$')

ax.set_title('{:.1f} MHz'.format(1e-6 * sss.sweep.resonator.f_0))
ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('spectral density [Hz$^{-1}$]')
ax.legend(loc='best', fontsize='small');

# %% [markdown]
# # ADC snaps

# %%
snaps = [ncf.read(name) for name in ncf.node_names() if name.startswith('ADCSnap')]

# %%
[snap.x.ptp() for snap in snaps]
# Out:
# [2025.0, 887.0, 429.0, 223.0, 109.0]

# %%
[snap.y.ptp() for snap in snaps]
# Out:
# [32.0, 31.0, 33.0, 33.0, 31.0]

# %% [markdown]
# # Raw sweep data

# %%
sss = ssas[3][0]

# %%
sss.resonator.f_0
# Out:
# 78330371.039615393

# %%
sss.resonator.Q_e_real
# Out:
# 66154.168867342989

# %%
sss.resonator.Q_i
# Out:
# 35021.150795957044

# %%
fig, ax = plt.subplots(figsize=(2, 2))
ax.set_xlabel(r'$\mathfrak{Re} \; S_{21}$')
ax.set_ylabel(r'$\mathfrak{Im} \; S_{21}$')

for stream in sss.sweep.streams:
    ax.plot(stream.s21_raw.real,
            stream.s21_raw.imag,
            ',k')
    
ax.plot(sss.sweep.s21_point.real,
        sss.sweep.s21_point.imag,
        '.r', markersize=2)

ax.set_xlim(1e4, 3e4)
ax.set_ylim(1.8e4, 3.8e4)

fig.savefig('raw_s21.png', bbox_inches='tight')

# %%
stream = sss.sweep.streams[48]

fig, ax = plt.subplots(figsize=(4, 1.5))
ax.set_xlabel('time [s]')
ax.set_ylabel('$|S_{21}|$')

ax.plot(stream.sample_time,
        np.abs(stream.s21_raw),
        '-k')
ax.set_xlim(-0.01, 0.14)
ax.set_ylim(2.6e4, 3.2e4)

fig.savefig('stream_s21_tod.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(4, 1.5))
ax.set_xlabel('time [s]')
ax.set_ylabel('$|S_{21}|$')

ax.plot(stream.sample_time,
        np.abs(stream.s21_raw),
        '-k')
ax.set_xlim(0., 0.005)
ax.set_ylim(2.6e4, 3.2e4)

fig.savefig('stream_s21_tod_detail.png', bbox_inches='tight')

# %%
from kid_readout.roach import calculate

# %%
np.log2(stream.s21_raw.size)
# Out:
# 11.0

# %%
fig, ax = plt.subplots()
ax.set_xlabel('frequency [Hz]')
ax.set_ylabel('PSD of $S_{21}$')
S, f = plt.mlab.psd(stream.s21_raw, Fs=calculate.stream_sample_rate(stream.roach_state), NFFT=2**11, sides='onesided')
ax.loglog(f, np.abs(S), '-k')
ax.set_ylim(1e-2, 1e4)
fig.savefig('psd.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots()
ax.plot(jump.stream.sample_time, jump.x, ',b')
ax.plot(jump.stream.sample_time, jump.q, ',g')

# %%
calculate.stream_sample_rate(sss.stream.roach_state)
# Out:
# 15625.0

# %%
tau_r = sss.resonator.Q / (np.pi * sss.resonator.f_0)
tau_r
# Out:
# 9.4323343878819258e-05

# %%
bw_r = 1 / (2 * np.pi * tau_r)
bw_r
# Out:
# 1687.3335544207134
