# %% [markdown]
# This data set was superseded by one taken a few weeks later.

# %%
from kid_readout.analysis import archive
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
df = archive.build_simple_archives('/home/data/pkl/*2014-12-08*.pkl')
# Out:
# failed to pickle [Errno 1] Operation not permitted: '/home/data/archive/2014-12-08_191404_32.0_dB_260_mK.npy'
# failed to pickle
#  [Errno 1] Operation not permitted: '/home/data/archive/2014-12-08_180606_41.0_dB_230_mK.npy'
# failed to pickle
#  [Errno 1] Operation not permitted: '/home/data/archive/2014-12-08_135527_38.0_dB.npy'
# failed to pickle
#  [Errno 1] Operation not permitted: '/home/data/archive/2014-12-08_154517_32.0_dB_160_mK.npy'
# failed to pickle
#  [Errno 1] Operation not permitted: '/home/data/archive/2014-12-08_185755_38.0_dB_260_mK.npy'
# failed to pickle
#  [Errno 1] Operation not permitted: '/home/data/archive/2014-12-08_142009_29.0_dB.npy'
# failed to pickle
#  [Errno 1] Operation not permitted: '/home/data/archive/2014-12-08_153709_35.0_dB_160_mK.npy'
# failed to pickle
#  [Errno 1] Operation not permitted: '/home/data/archive/2014-12-08_183015_32.0_dB_230_mK.npy'
# failed to pickle
# ...

# %%
r0 = df[df.resonator_id==0]

# %%
for name, group in r0.groupby('atten'):
    group = group.sort('sweep_primary_package_temperature')
    plt.plot(group.sweep_primary_package_temperature, group.f_0, '.-', label=name)
plt.legend(loc='best')

# %%
r0.atten
# Out:
# 0      32
# 16     41
# 32     38
# 48     32
# 64     38
# 80     29
# 96     35
# 112    32
# 128    38
# 144    41
# 160    29
# 176    41
# 192    35
# 208    29
# 224    41
# 240    32
# 256    38
# 272    35
# 288    29
# 304    32
# 320    38
# 336    35
# 352    38
# 368    35
# 384    29
# 400    41
# 416    29
# 432    35
# 448    41
# 464    32
# Name: atten, dtype: float64
