# %%
import os
from kid_readout.utils import readoutnc
from kid_readout.analysis import archive, dataframe, plot_dataframe
plt.rcParams['font.size'] = 11
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
archive_filename = '2015-05-05_magnetic_pickup'
full_archive_filename = os.path.join('/home/data/archive', archive_filename + '.npy')

# %%
pkls = ['2015-05-05_102201_magnetic_pickup.pkl']
df = archive.build_simple_archive([os.path.join('/home/data/pkl/', pkl) for pkl in pkls],
                                  archive_name=archive_filename)
df.shape
# Out:
# (64, 88)

# %%
channel_to_location = np.array([0, 1, 2, 3, 4, 5, 8, 9, 10, 12, 13, 15, 16, 17, 18, 19])
df = dataframe.analyze(df, channel_to_location=channel_to_location)
channels = sorted(set(df.channel))
dark_channels = (0, 2, 4, 10)
df.shape
# Out:
# (64, 98)

# %%
df[df.channel==0].atten
# Out:
# 0     41
# 1     41
# 32    35
# 33    35
# Name: atten, dtype: float64

# %%
[plot_dataframe.plot_pca_noise(df, c, color_key='atten', plot_row_0=False) for c in channels];

# %%
[plot_dataframe.plot_sweeps(df, c, color_key='atten') for c in channels];

# %%
[plot_dataframe.plot_sweeps_IQ(df, c, color_key='atten') for c in channels];
