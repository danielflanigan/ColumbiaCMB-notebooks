# %% [markdown]
# # These nc files were acquired incorrectly and were deleted.

# %%
from kid_readout.analysis import noise_measurement
plt.rcParams['font.size'] = 11
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# This guy has a huge spike in the middle of the timestream:

# %% [markdown]
# snms33 = [noise_measurement.SweepNoiseMeasurement('/home/data2/2014-11-20_115148_second_pass_noise.nc',
#                                                   delay_estimate=-63,
#                                                   resonator_index=n)
#           for n in range(16)]

# %%
snms33 = [noise_measurement.SweepNoiseMeasurement('/home/data2/2014-11-20_130116_second_pass_noise.nc',
                                                  delay_estimate=None,
                                                  resonator_index=n)
          for n in range(16)]
# Out:
# using NFFT: 2** 19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# using NFFT: 2**
#  19.0
# 2
# /home/flanigan/kid_readout.git/kid_readout/analysis/iqnoise.py:75: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[0,k] = ss[0,0]
# /home/flanigan/kid_readout.git/kid_readout/analysis/iqnoise.py:76: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[1,k] = ss[1,1]

# %%
fig = snms33[0].plot()

# %%
fig = snms33[1].plot()

# %%
fig = snms33[1].plot()

# %%
fig = snms33[2].plot()

# %%
from kid_readout.utils import readoutnc
nc = readoutnc.ReadoutNetCDF('/home/data2/2014-11-20_130116_second_pass_noise.nc')

# %%
nc.timestream_20141120131610.measurement_freq
# Out:
# array([ 96.06530762])
