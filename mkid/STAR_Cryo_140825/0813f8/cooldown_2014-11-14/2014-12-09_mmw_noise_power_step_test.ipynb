# %% [markdown]
# To do:
#
# check that this data is fine except for the dropped packets, and understand what effect they have
#
# the problem in mmw_noise_power_steps has to have something to do with adding extra tone frequencies or selecting the best waveform.

# %%
import pickle
#from kid_readout.analysis import noise_archive # This is outdated

# %%
filename = '/home/data/mmw_noise_steps_2014-12-09_165910_mmwnoisestep_test.pkl'
with open(filename, 'r') as f:
    data = pickle.load(f)
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
data.keys()
# Out:
# ['noise_modulated_measurements', 'noise_on_measurements', 'noise_off_sweeps']

# %%
# %run ~/kid_readout.git/apps/data_analysis_scripts/mmw_source_archive.py
# Out:
# Loaded noise archive from: /home/data/archive/mmw_noise_steps_2014-12-09_165910_mmwnoisestep_test.npy

# %%
[column for column in df.columns]
# Out:
# ['index',
#  'A_mag',
#  'A_mag_err',
#  'A_phase',
#  'A_phase_err',
#  'Q',
#  'Q_e_imag',
#  'Q_e_imag_err',
#  'Q_e_real',
#  'Q_e_real_err',
#  'Q_err',
#  'Q_i',
#  'a',
#  'a_err',
#  'adc_sampling_freq_MHz',
#  'amplifier_noise',
#  'atten',
#  'chip_name',
#  'dac_chain_gain',
#  'deglitch_threshold',
#  'deglitch_window',
#  'delay',
#  'delay_err',
#  'device_noise',
#  'end_temp',
#  'experiment_description',
#  'experiment_info',
#  'f_0',
#  'f_0_err',
#  'f_phi',
#  'f_phi_err',
#  'folded_projected_timeseries',
#  'freqs_coarse',
#  'is_dark',
#  'low_pass_normalized_timeseries',
#  'low_pass_projected_timeseries',
#  'low_pass_timestep',
#  'mmw_atten_turns',
#  'mmw_mod_duty_cycle',
#  'mmw_mod_freq',
#  'mmw_mod_phase',
#  'nfft',
#  'noise_measurement_freq_MHz',
#  'normalized_ds21_df_at_meas_freq',
#  'normalized_model_s21_at_meas_freq',
#  'normalized_model_s21_at_resonance',
#  'normalized_timeseries_mean',
#  'optical_state',
#  'pca_S',
#  'pca_angles',
# ...

# %%
df.pca_freq[0].shape
# Out:
# (137,)

# %%
df.pca_eigvals[0].shape
# Out:
# (2, 137)

# %%
plt.loglog(df.pca_freq[0], df.pca_eigvals[0][0])
plt.loglog(df.pca_freq[0], df.pca_eigvals[0][1])

# %%
df.ix[0]
# Out:
# index                               0
# A_mag                      0.03485752
# A_mag_err                5.214111e-06
# A_phase                             0
# A_phase_err                         0
# Q                            63691.54
# Q_e_imag                     29747.03
# Q_e_imag_err                 215.9458
# Q_e_real                     83826.62
# Q_e_real_err                 223.7188
# Q_err                        177.9347
# Q_i                          195866.5
# a                                 NaN
# a_err                             NaN
# adc_sampling_freq_MHz             512
# ...
# timestream_modulation_duty_cycle                                                            0
# timestream_modulation_freq                                                                  0
# timestream_modulation_period_samples                                                        0
# timestream_modulation_phase                                                                 0
# ...
