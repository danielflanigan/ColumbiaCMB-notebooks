# %%
from kid_readout.utils import roach_interface
from kid_readout.utils import sweeps, data_file
from kid_readout.analysis import resonator
from kid_readout.analysis import plot_resonator

# %%
ri = roach_interface.RoachBaseband()
# Out:
# Loaded ROACH state from /home/data/roach_config.npz

# %%
all_f0s = np.load('/home/data2/resonances/2014-11-17_0813f8_140825-3_second_pass.npy')

# %%
all_f0s[9]
# Out:
# 164.37695299999999

# %%
f0s = np.concatenate([all_f0s[0:9], all_f0s[10:17]]) # Upper limit was 18

# %%
nsamp = 2**20
step = 1
nstep = 20
f0binned = np.round(f0s*nsamp/512.0)*512.0/nsamp
offset_bins = np.arange(-(nstep+1),(nstep+1))*step

offsets = offset_bins*512.0/nsamp
#offsets = np.concatenate(([offsets.min()-20e-3,],offsets,[offsets.max()+20e-3]))

# %%
ri.set_dac_atten(39)

# %%
measured_freqs = sweeps.prepare_sweep(ri, f0binned, offsets, nsamp=nsamp)
# Out:
# bank_offset= 0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# writing DRAM bank 1
# writing DRAM bank 2

# %%
measured_freqs.shape
# Out:
# (42, 16)

# %%
offsets.shape
# Out:
# (42,)

# %%
offset_bins.shape
# Out:
# (42,)

# %%
sweep_data = sweeps.do_prepared_sweep(ri, nchan_per_step=16, reads_per_step=1)

# %%
sample = 4
block = sample * 2**12

# %%
sweep_data.data.shape
# Out:
# (672,)

# %%
16 * 164
# Out:
# 2624

# %%
blk = sweep_data.blocks[0]

# %%
blk.data.shape
# Out:
# (4096,)

# %% [markdown]
# one data block = 16kB * n_channels

# %%
rs = [resonator.Resonator(f, s21, errors=errors) for f, s21, errors in
      [sweep_data.select_index(n) for n in range(16)]]

# %%
fig = plot_resonator.IQ_circle(rs[0], normalize_s21=True, points=1e4)

# %%
fig = plot_resonator.IQ_circle(rs[1], normalize_s21=True, points=1e4)

# %%
fig = plot_resonator.IQ_circle(rs[2], normalize_s21=True, points=1e4)

# %%
Q_i = [r.Q_i for r in rs]
Q_c = [abs(r.Q_e) for r in rs]
f_0 = [r.f_0 for r in rs]

# %%
plt.plot(f_0, Q_i, '.')
plt.plot(f_0, Q_c, '.')

# %%
fig = plot_resonator.IQ_circle(rs[np.argmax(Q_i)], normalize_s21=True, points=1e4)

# %%
fig = plot_resonator.amplitude_and_phase(rs[np.argmax(Q_i)], normalize_s21=True, points=1e4)

# %%
fig = plot_resonator.amplitude_and_phase(rs[np.argmax(Q_i)-1], normalize_s21=True, points=1e4)

# %% [markdown]
# ADC sample rate is 512 MS/s; chunks of 2^15 real samples get FFTed and produce 2^14 complex samples;
# RoachBaseband uses NFFT = 2^14; RoachBasebandWide uses NFFT = 2^10

# %%
blk.fs
# Out:
# 512.0

# %%
blk.nfft
# Out:
# 16384

# %%
plt.semilogy([r.result.redchi for r in rs], '.')

# %%
plt.plot(np.array(sorted(f_0)) - f0s)

# %%
np.save('/home/data2/resonances/2014-11-17_0813f8_140825-3_fit_16.npy', sorted(f_0))
