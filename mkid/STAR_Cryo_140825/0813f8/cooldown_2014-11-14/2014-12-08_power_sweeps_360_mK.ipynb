# %% [markdown]
# This data set wasn't collected because the frequencies were too far off. Need to increase the spacing for higher temperatures and track the resonance shift.

# %%
from kid_readout.utils import roach_interface
from kid_readout.utils import acquire
from kid_readout.analysis import resonator, plot_resonator, noise_measurement
plt.rcParams['font.size'] = 11
# Out:
# updated file list
# /home/local/lib/python2.7/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
roach = roach_interface.RoachBaseband()
# Out:
# Loaded ROACH state from /home/data/roach_config.npz

# %%
attenuations = [41, 38, 35, 32, 29]
sweep_n_samples = timestream_n_samples = 2**21
center_freqs = np.load('/home/data2/resonances/2014-12-06_140825_0813f8_fit_16.npy')
offset_freqs = roach.fs / sweep_n_samples * (acquire.offset_integers_31 - 20)
time_in_seconds = 30

# %%
roach.set_dac_atten(35)
coarse, fine = acquire.coarse_fit_fine(roach, center_freqs, 2 * acquire.offset_integers_31,
                                       sweep_n_samples, coarse_multiplier=8)
# Out:
# bank_offset= 0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# writing DRAM bank 1
# writing DRAM bank 2
# writing DRAM bank 3
# detected mcnt overflow
#  None 2137456 0 16384 0 320 2137456
# bank_offset=
#  0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# writing DRAM bank 1
# writing DRAM bank 2
# writing DRAM bank 3
# detected mcnt overflow
#  None 40314 0 16384 0 416 40314

# %%
rc = acquire.fit_sweep_data(coarse)
[plot_resonator.amplitude_and_phase(r) for r in rc]

# %%
rf = acquire.fit_sweep_data(fine)
figs = [plot_resonator.amplitude_and_phase(r, normalize_s21=True) for r in rf]
