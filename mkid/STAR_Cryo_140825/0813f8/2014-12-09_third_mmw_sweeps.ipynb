# %% [markdown]
# Regulating at 130 mK; stage at 150 mK. Second sweeps used old resonance frequencies.

# %%
# %run ~/kid_readout.git/apps/data_taking_scripts/mmw_source_sweep_140825_0813f8.py
# Out:
# Stanford_Research_Systems,SR830,s/n45571,ver1.07
# Loaded ROACH state from
#  /home/data/roach_config.npz
# modulating at:
#  122.0703125
# [  96.06355773  101.96523367  108.86657801  112.26638273  117.27724207
#   127.78603442  144.19483163  148.24979368  164.08665897  164.37767102
#   165.41384075  174.96136838  178.94318276  184.56448522  188.8678925
#   195.71639439]
# [-100078.125  -80078.125  -78125.     -76171.875  -74218.75   -72265.625
#   -70312.5    -68359.375  -66406.25   -64453.125  -62500.     -60546.875
#   -58593.75   -56640.625  -54687.5    -52734.375  -50781.25   -48828.125
#   -46875.     -44921.875  -42968.75   -41015.625  -39062.5    -37109.375
#   -35156.25   -33203.125  -31250.     -29296.875  -27343.75   -25390.625
#   -23437.5    -21484.375  -19531.25   -17578.125  -15625.     -13671.875
#   -11718.75    -9765.625   -7812.5     -5859.375   -3906.25    -1953.125
#        0.       1953.125    3906.25     5859.375    7812.5      9765.625
#    11718.75    13671.875   15625.      17578.125   19531.25    21484.375
#    23437.5     25390.625   27343.75    29296.875   31250.      33203.125
#    35156.25    37109.375   39062.5     41015.625   42968.75    44921.875
#    46875.      48828.125   50781.25    52734.375   54687.5     56640.625
#    58593.75    60546.875   62500.      64453.125   66406.25    68359.375
#    70312.5     72265.625   74218.75    76171.875   78125.      98125.   ]
# 16
# setting attenuator to 39
# bank_offset=
#  0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# writing DRAM bank 1
# loaded waveforms in 48.4171710014 seconds
# detected mcnt overflow
#  None 302458 0 16384 0 912 302458
# detected mcnt overflow
#  None 1219961 0 16384 0 736 1219961
# detected mcnt overflow
#  None 2661751 0 16384 0 544 2661751
# detected mcnt overflow
#  None 3186038 0 16384 0 320 3186038
# detected mcnt overflow
#  None 695668 0 16384 0 80 695668
# s21 fmin
#  96.0625 original guess 96.063557734 this fit 96.0637642528 delay -63.3136652164 resid delay -0.000106143163069
# using this fit
# s21 fmin 101.96484375 original guess 101.965233674 this fit 101.96492816 delay -63.3063482331 resid delay -0.0049322802679
# using this fit
# s21 fmin
#  108.865234375 original guess 108.866578006 this fit 108.865803396 delay -63.3111972063 resid delay 0.00404578580678
# using this fit
# s21 fmin
#  112.265625 original guess 112.266382729 this fit 112.266424132 delay -63.3110760527 resid delay -0.000184836491381
# using this fit
# s21 fmin
#  117.27734375 original guess 117.277242071 this fit 117.27723468 delay -63.3119263567 resid delay -0.000246383776158
# using this fit
# s21 fmin
#  127.78515625 original guess 127.786034424 this fit 127.785938573 delay -63.3126575014 resid delay 0.000124050799867
# using this fit
# s21 fmin
#  144.1953125 original guess 144.19483163 this fit 144.19491685 delay -63.3128443699 resid delay 0.00057707331861
# using this fit
# s21 fmin
#  148.25 original guess 148.249793685 this fit 148.24977949 delay -63.3113852655 resid delay -0.0001612683649
# using this fit
# s21 fmin
#  164.0859375 original guess 164.086658969 this fit 164.086929636 delay -63.3061990626 resid delay 3.70655358049e-05
# using this fit
# s21 fmin 164.376953125 original guess 164.377671023 this fit 164.376955774 delay -63.2710091308 resid delay -0.111271243461
# using this fit
# s21 fmin
#  165.4140625 original guess 165.413840749 this fit 165.413852011 delay -63.3102072126 resid delay -5.54354800428e-06
# using this fit
# s21 fmin
#  174.9609375 original guess 174.961368383 this fit 174.961274224 delay -63.3115871646 resid delay -0.000136740044426
# using this fit
# s21 fmin
#  178.9453125 original guess 178.94318276 this fit 178.943398858 delay -63.3113936975 resid delay -6.11998384389e-06
# using this fit
# s21 fmin
#  184.564453125 original guess 184.564485216 this fit 184.564482733 delay -63.3106558503 resid delay 9.98739947273e-05
# using this fit
# s21 fmin
#  188.869140625 original guess 188.867892498 this fit 188.867876265 delay -63.3072610689 resid delay -0.00015075027664
# using this fit
# s21 fmin
#  195.716796875 original guess 195.716394392 this fit 195.716581745 delay -63.2903176823 resid delay -0.0178143213248
# using this fit
# median delay is  -63.3111366295
# bank_offset=
#  0 start_offset= 0 start_offset_bytes= 0
# writing DRAM bank 0
# writing DRAM bank 1
# writing DRAM bank 2
# loaded updated waveforms in 272.030173063 seconds
# s21 fmin 96.0635986328 original guess 96.0637207031 this fit 96.0637948145
# using this fit
# s21 fmin 101.965209961 original guess 101.96496582 this fit 101.965285898
# using this fit
# s21 fmin
#  108.866333008 original guess 108.865844727 this fit 108.866575885
# using this fit
# s21 fmin 112.266479492 original guess 112.266479492 this fit 112.266536017
# using this fit
# s21 fmin
#  117.277099609 original guess 117.27722168 this fit 117.277227116
# using this fit
# s21 fmin
#  127.785888672 original guess 127.785888672 this fit 127.785992607
# using this fit
# s21 fmin
#  144.194946289 original guess 144.194946289 this fit 144.194935642
# using this fit
# s21 fmin
#  148.249755859 original guess 148.249755859 this fit 148.249778428
# using this fit
# s21 fmin 164.086669922 original guess 164.086914062 this fit 164.086935294
# using this fit
# s21 fmin
#  164.377441406 original guess 164.376953125 this fit 164.377612045
# using this fit
# s21 fmin
#  165.413818359 original guess 165.413818359 this fit 165.41385387
# using this fit
# s21 fmin
#  174.96105957 original guess 174.961303711 this fit 174.961282287
# using this fit
# s21 fmin 178.9453125 original guess 178.943359375 this fit 178.943413264
# using this fit
# s21 fmin
#  184.564453125 original guess 184.564453125 this fit 184.564467655
# using this fit
# s21 fmin 188.869140625 original guess 188.867919922 this fit 188.867879762
# using this fit
# s21 fmin
#  195.716796875 original guess 195.716552734 this fit 195.716569015
# using this fit
# [96.063794814516967, 101.9652858978797, 108.86657588490507, 112.26653601688328, 117.27722711584126, 127.78599260736392, 144.19493564241401, 148.24977842750943, 164.08693529390686, 164.37761204498676, 165.41385386963989, 174.96128228741168, 178.94341326374524, 184.56446765503293, 188.86787976215194, 195.71656901541198]
# bank_offset=
#  3 start_offset= 100663296 start_offset_bytes= 0
# writing DRAM bank 3
# 135000000000.0
#  135060120240.0
# 135120240481.0
# detected mcnt overflow None 40312 0 16384 0 480 40312
# 135180360721.0
#  135240480962.0
# 135300601202.0
# 135360721443.0
# 135420841683.0
# 135480961924.0
# 135541082164.0
# 135601202405.0
# 158386773547.0
# 158446893788.0
# detected mcnt overflow None 40312 0 16384 0 1648 40312
# 158507014028.0
#  158567134269.0
# 158627254509.0
# 158687374749.0
# 158747494990.0
# 158807615230.0
# 158867735471.0
# detected mcnt overflow None 40312 0 16384 0 896 40312
# 158927855711.0
#  158987975952.0
# 159048096192.0
# 159108216433.0
# 159168336673.0
# 159228456914.0
# 159288577154.0
# detected mcnt overflow None 40312 0 16384 0 240 40312
# 159348697395.0
#  159408817635.0
# 159468937876.0
# 159529058116.0
# 159589178357.0
# 159649298597.0
# detected mcnt overflow None 40312 0 16384 0 1952 40312
# 159709418838.0
#  159769539078.0
# 159829659319.0
# 159889779559.0
# 159949899800.0
# 160010020040.0
# 160070140281.0
# detected mcnt overflow None 40312 0 16384 0 1200 40312
# 160130260521.0
#  160190380762.0
# 160250501002.0
# 160310621242.0
# 160370741483.0
# 160430861723.0
# 160490981964.0
# detected mcnt overflow None 40312 0 16384 0 432 40312
# 160551102204.0
#  160611222445.0
# 160671342685.0
# 160731462926.0
# 160791583166.0
# 160851703407.0
# 160911823647.0
# 160971943888.0
# 161032064128.0
# 161092184369.0
# 161152304609.0
# 161212424850.0
# 161272545090.0
# detected mcnt overflow None 40312 0 16384 0 1392 40312
# 161332665331.0
#  161392785571.0
# 161452905812.0
# 161513026052.0
# 161573146293.0
# 161633266533.0
# 161693386774.0
# detected mcnt overflow None 40312 0 16384 0 672 40312
# 161753507014.0
#  161813627255.0
# 161873747495.0
# 161933867735.0
# 161993987976.0
# 162054108216.0
# 162114228457.0
# 162174348697.0
# 162234468938.0
# 162294589178.0
# 162354709419.0
# 162414829659.0
# 162474949900.0
# detected mcnt overflow None 40312 0 16384 0 1696 40312
# 162535070140.0
#  162595190381.0
# 162655310621.0
# 162715430862.0
# 162775551102.0
# 162835671343.0
# 162895791583.0
# detected mcnt overflow None 40312 0 16384 0 1040 40312
# 162955911824.0
#  163016032064.0
# 163076152305.0
# 163136272545.0
# 163196392786.0
# 163256513026.0
# 163316633267.0
# detected mcnt overflow None 40312 0 16384 0 320 40312
# 163376753507.0
#  163436873747.0
# 163496993988.0
# 163557114228.0
# 163617234469.0
# 163677354709.0
# 163737474950.0
# 163797595190.0
# 163857715431.0
# 163917835671.0
# 163977955912.0
# 164038076152.0
# 164098196393.0
# detected mcnt overflow None 40312 0 16384 0 1424 40312
# 164158316633.0
#  164218436874.0
# 164278557114.0
# 164338677355.0
# 164398797595.0
# 164458917836.0
# 164519038076.0
# detected mcnt overflow None 40312 0 16384 0 752 40312
# 164579158317.0
#  164639278557.0
# 164699398798.0
# 164759519038.0
# 164819639279.0
# 164879759519.0
# 164939879760.0
# detected mcnt overflow None 40312 0 16384 0 96 40312
# 165000000000.0
#  done with sweep
# completed in
#  25.8962397814 minutes

# %%
from kid_readout.analysis import process_mmw_response, plot_resonator
from kid_readout.analysis.resources import skip5x4

# %%
def scatter(values, mask=None, colormap=plt.cm.copper, size=200, colorbar=True, **kwargs):
    x = skip5x4.coordinate_array[:, 0]
    y = skip5x4.coordinate_array[:, 1]
    if mask is None:
        mask = np.ones_like(values, dtype=np.bool)
    fig, ax = plt.subplots()
    ax.scatter(x[mask], y[mask], c=values, s=size, cmap=colormap, edgecolor='None', **kwargs)
    if colorbar:
        mappable = plt.cm.ScalarMappable(matplotlib.colors.Normalize(min(values), max(values)), cmap=plt.cm.copper)
        mappable.set_array(values)
        cb = fig.colorbar(mappable)
    return fig, ax

def scatter_text(values, **kwargs):
    x_offset = -0.5
    y_offset = 0.15
    fig, ax = scatter(values, **kwargs)
    for n in range(20):
        ax.text(skip5x4.coordinate_array[:,0][n] + x_offset,
                skip5x4.coordinate_array[:,1][n] + y_offset,
                '{:.0f}: {:.2f}'.format(n, skip5x4.nominal_frequencies[n]),
                fontdict={'fontsize': 'xx-small'})
    ax.set_xlim(-1, 5)
    ax.set_ylim(-1, 5)
    return fig, ax

# %%
nc_filename = '/home/data2/2014-12-09_114434_mmw.nc'
mmws = sorted([process_mmw_response.MmwResponse(nc_filename, resonator_index=n) for n in range(16)],
              key=lambda mmw: mmw.resonator.f_0)
# Out:
# warning: inverse not yet defined for bifurcation model, proceeding anyway
# warning: inverse not yet defined for bifurcation model, proceeding anyway

# %%
fit_16 = np.load('/home/data2/resonances/2014-12-06_140825_0813f8_fit_16.npy')
read_out = np.array([x not in [6, 7, 12, 13] for x in range(20)])
zip(np.arange(20)[read_out],
    skip5x4.nominal_frequencies[read_out],
    fit_16,
    [mmw.resonator.f_0 for mmw in mmws])
# Out:
# [(0, 100.0, 96.063557733956969, 96.063796885995174),
#  (1, 105.0, 101.96523367408936, 101.96528455867006),
#  (2, 110.0, 108.86657800582901, 108.86657703989101),
#  (3, 115.0, 112.26638272879823, 112.2665338461136),
#  (4, 120.0, 117.27724207094199, 117.27716143999375),
#  (5, 130.0, 127.78603442364334, 127.78598737572086),
#  (8, 145.0, 144.19483163037432, 144.19493445202295),
#  (9, 150.0, 148.2497936846772, 148.24977428055223),
#  (10, 165.0, 164.08665896922273, 164.08693677895903),
#  (11, 165.25, 164.37767102259207, 164.37761542040892),
#  (14, 166.0, 165.41384074916715, 165.41385303329648),
#  (15, 175.0, 174.96136838253162, 174.9612849393061),
#  (16, 180.0, 178.94318276017904, 178.94341376758939),
#  (17, 185.0, 184.56448521638595, 184.56446911112866),
#  (18, 190.0, 188.86789249763575, 188.86788108922104),
#  (19, 195.0, 195.7163943919972, 195.71656727591005)]

# %%
bandwidth_GHz = 1e-9 * mmws[0].mmw_freq.ptp()
average_response_ppm_per_GHz = np.array([1e6 * np.trapz(mmw.mmw_frac_response, x=1e-9 * mmw.mmw_freq) for mmw in mmws]) / bandwidth_GHz

# %%
figs = [plt.plot(1e-9 * mmw.mmw_freq, 1e6 * mmw.mmw_frac_response, '-b') for mmw in mmws]

# %%
plt.plot([mmw.resonator.f_0 for mmw in mmws], average_response_ppm_per_GHz, '.')

# %%
fig, ax = scatter(average_response_ppm_per_GHz, mask=read_out)

# %%
fig, ax = scatter([mmw.resonator.Q_i for mmw in mmws], mask=read_out)

# %%
figs = [plot_resonator.IQ_circle(mmw.resonator, normalize_s21=True, points=1e4) for mmw in mmws]
