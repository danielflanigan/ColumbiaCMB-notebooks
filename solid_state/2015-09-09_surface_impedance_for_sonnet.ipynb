# %%
from scipy.constants import h, pi, e
from physics.mkid import noroozian

# %%
sigma_aluminum = 3.538e7  # in S/m
thickness = 20e-9
T = 0.200
T_c = 1.2
f = np.linspace(2e9, 4e9, 100)
N_0 = noroozian.N_0_Al
Delta_0 = noroozian.BCS_Delta_0(T_c)
n_qp = noroozian.equation_2_3(T, Delta_0, N_0)
sigma_1 = sigma_aluminum * noroozian.equation_2_7(f, T, Delta_0, N_0, n_qp)
sigma_2 = sigma_aluminum * noroozian.equation_2_8(f, T, Delta_0, N_0, n_qp)

# %%
1e6 * Delta_0 / e  # in ueV
# Out:
# 181.99805997037538

# %%
plt.semilogy(f, sigma_1)
plt.semilogy(f, sigma_2)

# %%
sigma_1.mean()
# Out:
# 24307.229544325379

# %%
sigma_2.mean()
# Out:
# 1696520750.8660369

# %%
R_s = sigma_1.mean() / (thickness * sigma_2.mean()**2)
R_s
# Out:
# 4.2226697245494733e-07

# %%
X_s = 1 / (thickness * sigma_2.mean())
X_s
# Out:
# 0.02947208277557235
